# %%
import folium
from branca.element import Figure

fig=Figure(height=500,width=1000)
map=folium.Map(location=[17.30305896939215, 82.46636729978133],tiles='CartoDB Positron',zoom_start=8)
fig.add_child(map)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
cords1 = [[16.798897281055517, 80.84598354338551], [16.71699893093627, 80.9129677531224],[16.67154517108932, 80.94144008516261], [16.689727972648665, 80.99838474924303],
           [16.757898058127306, 81.20243646219785], [16.84421177385934, 81.28785345831848], [16.953183358562647, 81.42072434117279], [17.057555214513805, 81.57257677872057],
           [17.025796024688127, 81.69595688422812], [17.048481710969675, 81.77662849167538], [17.053018517836687, 81.82882776708244], [17.143731481049414, 81.96644403861012],
           [17.25706038973209, 82.14676880819809], [17.23440017507731, 82.20371341791852], [17.29256367361371, 82.44612610083544], [17.365977181388928, 82.53950988535628],
          [17.423638600041418, 82.76472960096531], [17.59651341065989, 82.87459287687216], [17.64363830547045, 82.90032715985663], [17.69074503446223, 83.01019043576348],
          [17.795382396483692, 83.11456054787496], [17.86336382859654, 83.31231444450731], [17.926092857610218, 83.40020506523277], [17.97835008617333, 83.43316404800483], 
          [18.12980847368231, 83.57049314288838], [18.244620619434468, 83.74627438433932], [18.26548742427625, 83.79021969470207], [18.30721352592331, 83.78198009133297],
          [18.364570781654283, 83.78482638580947]]

cords2 = [[16.783288285398992, 80.84847742278724], [16.639921823815683, 80.96658045290336], [16.726743741015348, 81.03387171424858], [16.74121022322554, 81.13137537864675],
          [16.81615528903695, 81.24261195352354], [16.95282077471486, 81.39779383509772], [16.984344886289016, 81.47607142482583], [17.02505568987652, 81.65459926104785],
           [16.997478370015504, 81.77544887325966], [17.000104956358026, 81.80840785840834], [17.158186608112388, 82.04039846861964],
          [17.66578199089782, 82.61870194624728], [17.834017548017183, 83.18297653805082], 
          [18.267508975042194, 83.77074506415245], [18.350950116481716, 83.75975873656176] ]


f1=folium.FeatureGroup("Way to my home")
line=folium.vector_layers.PolyLine(cords1,popup='<b>Path to my home</b>',tooltip='Way 1',color='green',weight=4).add_to(f1)


f2=folium.FeatureGroup("Way to my home 2")
line1 =folium.vector_layers.PolyLine(cords2,popup='<b>Path to my home 2</b>',tooltip='Way 2',color='blue',weight=4).add_to(f2)


f1.add_to(map)
f2.add_to(map)

folium.LayerControl().add_to(map)


folium.Marker(location=[18.364570781654283, 83.78482638580947],popup='Ponduru',tooltip='HOME',icon=folium.Icon(color='red',prefix = 'fa', icon='fa-home')).add_to(map)
folium.Marker(location=[16.798897281055517, 80.84598354338551],popup='Starting',tooltip='NUZVID',icon=folium.Icon(color='blue',prefix = 'fa', icon='fa-location-arrow')).add_to(map)
folium.Marker(location=[16.99685765743457, 81.80152642599198],popup='sapthagiri grameen bank',tooltip='Bank',icon=folium.Icon(color='red',prefix = 'fa', icon='fa-building')).add_to(map)
folium.Marker(location=[16.957571976698983, 81.40890765184477],popup='Dr.Venkatapathi',tooltip='Hospital',icon=folium.Icon(color='red',prefix = 'fa', icon='fa-medkit')).add_to(map)
folium.Marker(location=[17.690817431427234, 83.23541990123915],popup='Bar and restaurant',tooltip='Bar',icon=folium.Icon(color='red',prefix = 'fa', icon='fa-beer')).add_to(map)
folium.Marker(location=[17.372700567946183, 82.57373482456101],popup='Coffe and Pizza hut',tooltip='Coffee',icon=folium.Icon(color='red',prefix = 'fa', icon='fa-coffee')).add_to(map)


folium.Marker(location=[17.84994285386905, 82.48684643869149],popup='parking area',tooltip='Parking',icon=folium.Icon(color='red',prefix = 'fa', icon='fa-car')).add_to(map)



map
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
